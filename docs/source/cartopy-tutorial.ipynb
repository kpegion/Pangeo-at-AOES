# %% [markdown]
# # Making Maps using `Cartopy`

# %% [markdown]
# `Cartopy` is a Python map plotting package.  Combined with `matplotlib` is works well for making contour plots of maps for Climate Data Analysis

# %% [markdown]
# This notebook will demonstrate how to make map contour plots using `Cartopy` and `matplotlib`, including:
#     1. some stuff
#     2. some more stuff

# %%
import warnings

import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
